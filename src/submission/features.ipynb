# %% [markdown]
# # Setup

# %% [markdown]
# <div style="background-color: #ffebee; border: 2px solid #d32f2f; padding: 10px; border-radius: 5px; color: #b71c1c;">
#         <b>Caution:</b> The setup code below only needs to be run once per assignment. If you've already executed it, you can safely ignore this section and proceed to the <a href="#assignment-content" style="color: #d32f2f; text-decoration: underline;">Assignment Content</a>.
#     </div>

# %% [markdown]
# This will run through setup of all necessary dependencies to complete the assignment.

# %% [markdown]
# ## Install required tools

# %%
try:
  import google.colab
  IN_COLAB = True
except:
  IN_COLAB = False

if IN_COLAB:
    # fixing error like "No module named 'imp'"
    # !sed -i -e 's/from imp import reload/from importlib import reload/' /usr/local/lib/python3.12/dist-packages/IPython/extensions/autoreload.py
else:
  import os
  # add local dependencies to PATH (for uv installation)
  os.environ['PATH'] = '/usr/local/bin:$HOME/.local/bin:' + os.environ['PATH']
  # add conda dependencies to PATH (for conda installation)
  os.environ['PATH'] = '/opt/anaconda3:~/anaconda3:~:~/miniconda3:/opt/miniconda3:' + os.environ['PATH']

# %% [markdown]
# ## Install datasets

# %% [markdown]
# The code snippets below will mount your Google Drive folder (if in a Colab environment) and proceed to install the relevant datasets needed to complete the assignment.

# %%
if IN_COLAB:
    # TODO: For colab, Enter the foldername in your Google Drive
    # to the root of the assignment folder, where this notebook exists
    # e.g. 'XCS231N/XCS231N-A?/src/submission' # you need to update "A?" with the homework number
    FOLDERNAME = 'path to your submission folder, see the above description'
    WORK_DIR = '/content/drive/MyDrive/{}'.format(FOLDERNAME)
    # This mounts your Google Drive to the Colab VM.
    from google.colab import drive
    drive.mount('/content/drive')

    assert FOLDERNAME is not None, "[!] Enter the foldername."

    # Now that we've mounted your Drive, this ensures that
    # the Python interpreter of the Colab VM can load
    # python files from within it.
    import sys
    sys.path.append(WORK_DIR)
else:
    # on local or azure, FOLDERNAME is set automatically
    FOLDERNAME=os.getcwd()
    WORK_DIR = FOLDERNAME

print(f"FOLDERNAME: ", FOLDERNAME)
print(f"WORK_DIR: ", WORK_DIR)
# Out:
# FOLDERNAME:  /Users/sj/code/xcs231n/XCS231N-A1/src/submission
# WORK_DIR:  /Users/sj/code/xcs231n/XCS231N-A1/src/submission

# %%
print("Getting dataset: START")
# %cd $WORK_DIR/xcs231n/datasets
# !bash get_datasets.sh
# %cd $WORK_DIR
print("Getting dataset: DONE")
# Out:
# Getting dataset: START
# /Users/sj/code/xcs231n/XCS231N-A1/src/submission/xcs231n/datasets
# /Users/sj/code/xcs231n/XCS231N-A1/src/submission
# Getting dataset: DONE

# %% [markdown]
# # Package Manager Setup

# %% [markdown]
# Below you have the option to run through the installation of `uv` package manager. Optionally, you can still work with `conda`.

# %% [markdown]
# ## `uv` (preferred)

# %%
if not IN_COLAB:
  # %cd $WORK_DIR/../..
  # !source install.sh -r
  # !source .venv/bin/activate
# Out:
# /Users/sj/code/xcs231n/XCS231N-A1
# 📄 Wrote ARM macOS Python version to .python-version
# 🔄 Refreshing environment...
# 📦 Creating virtual environment: .venv
# Using CPython 3.12.3
# Creating virtual environment at: .venv
# Activate with: source .venv/bin/activate
# 🔧 Syncing dependencies from pyproject.toml...
# Resolved 140 packages in 42ms
# Installed 119 packages in 627ms
#  + anyio==4.12.1
#  + appnope==0.1.4
#  + argon2-cffi==25.1.0
#  + argon2-cffi-bindings==25.1.0
#  + arrow==1.4.0
#  + asttokens==3.0.1
#  + async-lru==2.1.0
#  + attrs==25.4.0
#  + babel==2.18.0
#  + beautifulsoup4==4.14.3
#  + bleach==6.3.0
#  + certifi==2026.1.4
#  + cffi==2.0.0
#  + charset-normalizer==3.4.4
#  + comm==0.2.3
#  + contourpy==1.3.3
#  + cycler==0.12.1
#  + cython==3.2.2
#  + debugpy==1.8.20
#  + decorator==5.2.1
#  + defusedxml==0.7.1
#  + executing==2.2.1
#  + fastjsonschema==2.21.2
#  + filelock==3.24.2
#  + fonttools==4.61.1
#  + fqdn==1.5.1
#  + fsspec==2026.2.0
#  + future==1.0.0
#  + h11==0.16.0
#  + h5py==3.15.1
#  + httpcore==1.0.9
#  + httpx==0.28.1
#  + idna==3.11
#  + imageio==2.37.2
#  + ipykernel==7.2.0
#  + ipython==9.7.0
#  + ipython-pygments-lexers==1.1.1
#  + isoduration==20.11.0
#  + jedi==0.19.2
#  + jinja2==3.1.6
#  + joblib==1.5.3
#  + json5==0.12.1
#  + jsonpointer==3.0.0
#  + jsonschema==4.26.0
#  + jsonschema-specifications==2025.9.1
#  + jupyter-client==8.8.0
#  + jupyter-core==5.9.1
#  + jupyter-events==0.12.0
#  + jupyter-lsp==2.3.0
#  + jupyter-server==2.17.0
#  + jupyter-server-terminals==0.5.4
#  + jupyterlab==4.5.4
#  + jupyterlab-pygments==0.3.0
#  + jupyterlab-server==2.28.0
#  + kiwisolver==1.4.9
#  + lark==1.3.1
#  + markupsafe==3.0.3
#  + matplotlib==3.10.8
#  + matplotlib-inline==0.2.1
#  + mistune==3.2.0
#  + mpmath==1.3.0
#  + nbclient==0.10.4
#  + nbconvert==7.17.0
#  + nbformat==5.10.4
#  + nest-asyncio==1.6.0
#  + networkx==3.6.1
#  + notebook==7.5.0
#  + notebook-shim==0.2.4
#  + numpy==2.4.2
#  + packaging==26.0
#  + pandas==2.3.3
#  + pandocfilters==1.5.1
#  + parso==0.8.6
#  + pexpect==4.9.0
#  + pillow==12.0.0
#  + platformdirs==4.9.2
#  + prometheus-client==0.24.1
#  + prompt-toolkit==3.0.52
#  + psutil==7.2.2
#  + ptyprocess==0.7.0
#  + pure-eval==0.2.3
#  + pycparser==3.0
#  + pygments==2.19.2
#  + pyparsing==3.3.2
#  + python-dateutil==2.9.0.post0
#  + python-json-logger==4.0.0
#  + pytz==2025.2
#  + pyyaml==6.0.3
#  + pyzmq==27.1.0
#  + referencing==0.37.0
#  + requests==2.32.5
#  + rfc3339-validator==0.1.4
#  + rfc3986-validator==0.1.1
#  + rfc3987-syntax==1.1.0
#  + rpds-py==0.30.0
#  + scikit-learn==1.8.0
#  + scipy==1.16.3
#  + send2trash==2.1.0
#  + setuptools==82.0.0
#  + six==1.17.0
#  + soupsieve==2.8.3
#  + stack-data==0.6.3
#  + sympy==1.14.0
#  + terminado==0.18.1
#  + thop==0.1.1.post2209072238
#  + threadpoolctl==3.6.0
#  + tinycss2==1.4.0
#  + torch==2.10.0
#  + tornado==6.5.4
#  + tqdm==4.67.1
#  + traitlets==5.14.3
#  + typing-extensions==4.15.0
#  + tzdata==2025.3
#  + uri-template==1.3.0
#  + urllib3==2.6.3
#  + wcwidth==0.6.0
#  + webcolors==25.10.0
#  + webencodings==0.5.1
#  + websocket-client==1.9.0
# 🟡 No CUDA (Nvidia GPUs)-enabled system detected. Installing CPU/MPS compatible dependencies...
# Resolved 68 packages in 595ms
# ⠙ Preparing packages... (0/1)
# ⠙ Preparing packages... (0/1)-------------------     0 B/191.25 MiB
# ⠙ Preparing packages... (0/1)------------------- 16.00 KiB/191.25 MiB
# ⠙ Preparing packages... (0/1)------------------- 32.00 KiB/191.25 MiB
# ⠙ Preparing packages... (0/1)------------------- 48.00 KiB/191.25 MiB
# ⠙ Preparing packages... (0/1)------------------- 64.00 KiB/191.25 MiB
# ⠙ Preparing packages... (0/1)------------------- 80.00 KiB/191.25 MiB
# ⠙ Preparing packages... (0/1)------------------- 96.00 KiB/191.25 MiB
# ⠙ Preparing packages... (0/1)------------------- 112.00 KiB/191.25 MiB
# ⠙ Preparing packages... (0/1)------------------- 128.00 KiB/191.25 MiB
# ⠙ Preparing packages... (0/1)------------------- 144.00 KiB/191.25 MiB
# ⠙ Preparing packages... (0/1)------------------- 160.00 KiB/191.25 MiB
# ⠙ Preparing packages... (0/1)------------------- 176.00 KiB/191.25 MiB
# ⠙ Preparing packages... (0/1)------------------- 192.00 KiB/191.25 MiB
# ⠙ Preparing packages... (0/1)------------------- 208.00 KiB/191.25 MiB
# ⠙ Preparing packages... (0/1)------------------- 224.00 KiB/191.25 MiB
# ⠙ Preparing packages... (0/1)------------------- 240.00 KiB/191.25 MiB
# ⠙ Preparing packages... (0/1)------------------- 256.00 KiB/191.25 MiB
# ⠙ Preparing packages... (0/1)------------------- 272.00 KiB/191.25 MiB
# ⠙ Preparing packages... (0/1)------------------- 288.00 KiB/191.25 MiB
# ⠹ Preparing packages... (0/1)------------------- 368.00 KiB/191.25 MiB
# ⠹ Preparing packages... (0/1)------------------- 1.04 MiB/191.25 MiB
# ⠹ Preparing packages... (0/1)------------------- 1.54 MiB/191.25 MiB
# ⠹ Preparing packages... (0/1)------------------- 1.70 MiB/191.25 MiB
# ⠸ Preparing packages... (0/1)------------------- 1.71 MiB/191.25 MiB
# ⠸ Preparing packages... (0/1)------------------- 2.02 MiB/191.25 MiB
# ⠸ Preparing packages... (0/1)------------------- 2.23 MiB/191.25 MiB
# ⠸ Preparing packages... (0/1)------------------- 2.54 MiB/191.25 MiB
# ⠸ Preparing packages... (0/1)------------------- 2.91 MiB/191.25 MiB
# ⠼ Preparing packages... (0/1)------------------- 3.34 MiB/191.25 MiB
# ⠼ Preparing packages... (0/1)------------------- 4.34 MiB/191.25 MiB
# ⠼ Preparing packages... (0/1)------------------- 4.82 MiB/191.25 MiB
# ⠴ Preparing packages... (0/1)------------------- 5.79 MiB/191.25 MiB
# ⠴ Preparing packages... (0/1)------------------- 6.03 MiB/191.25 MiB
# ⠴ Preparing packages... (0/1)------------------- 6.05 MiB/191.25 MiB
# ⠴ Preparing packages... (0/1)------------------- 6.45 MiB/191.25 MiB
# ⠴ Preparing packages... (0/1)------------------- 6.58 MiB/191.25 MiB
# ⠦ Preparing packages... (0/1)------------------- 6.97 MiB/191.25 MiB
# ⠦ Preparing packages... (0/1)------------------- 7.49 MiB/191.25 MiB
# ⠦ Preparing packages... (0/1)------------------- 7.77 MiB/191.25 MiB
# ⠦ Preparing packages... (0/1)------------------- 8.42 MiB/191.25 MiB
# ⠧ Preparing packages... (0/1)------------------- 9.12 MiB/191.25 MiB
# ⠧ Preparing packages... (0/1)------------------- 10.02 MiB/191.25 MiB
# ⠧ Preparing packages... (0/1)------------------- 10.97 MiB/191.25 MiB
# ⠧ Preparing packages... (0/1)------------------- 10.99 MiB/191.25 MiB
# ⠇ Preparing packages... (0/1)------------------- 11.02 MiB/191.25 MiB
# ⠇ Preparing packages... (0/1)------------------- 11.18 MiB/191.25 MiB
# ⠇ Preparing packages... (0/1)------------------- 11.36 MiB/191.25 MiB
# ⠇ Preparing packages... (0/1)------------------- 11.61 MiB/191.25 MiB
# ⠋ Preparing packages... (0/1)------------------- 11.78 MiB/191.25 MiB
# ⠋ Preparing packages... (0/1)------------------- 12.08 MiB/191.25 MiB
# ⠋ Preparing packages... (0/1)------------------- 12.32 MiB/191.25 MiB
# ⠋ Preparing packages... (0/1)------------------- 12.57 MiB/191.25 MiB
# ⠙ Preparing packages... (0/1)------------------- 12.83 MiB/191.25 MiB
# ⠙ Preparing packages... (0/1)------------------- 13.05 MiB/191.25 MiB
# ⠙ Preparing packages... (0/1)------------------- 13.07 MiB/191.25 MiB
# ⠙ Preparing packages... (0/1)------------------- 13.14 MiB/191.25 MiB
# ⠹ Preparing packages... (0/1)------------------- 13.29 MiB/191.25 MiB
# ⠹ Preparing packages... (0/1)------------------- 13.48 MiB/191.25 MiB
# ⠹ Preparing packages... (0/1)------------------- 13.73 MiB/191.25 MiB
# ⠹ Preparing packages... (0/1)------------------- 13.94 MiB/191.25 MiB
# ⠸ Preparing packages... (0/1)------------------- 14.20 MiB/191.25 MiB
# ⠸ Preparing packages... (0/1)------------------- 14.45 MiB/191.25 MiB
# ⠸ Preparing packages... (0/1)------------------- 14.71 MiB/191.25 MiB
# ⠼ Preparing packages... (0/1)------------------- 14.93 MiB/191.25 MiB
# ⠼ Preparing packages... (0/1)------------------- 14.97 MiB/191.25 MiB
# ⠼ Preparing packages... (0/1)------------------- 14.99 MiB/191.25 MiB
# ⠼ Preparing packages... (0/1)------------------- 15.20 MiB/191.25 MiB
# ⠼ Preparing packages... (0/1)------------------- 15.38 MiB/191.25 MiB
# ⠴ Preparing packages... (0/1)------------------- 15.57 MiB/191.25 MiB
# ⠴ Preparing packages... (0/1)------------------- 15.73 MiB/191.25 MiB
# ⠴ Preparing packages... (0/1)------------------- 15.95 MiB/191.25 MiB
# ⠴ Preparing packages... (0/1)------------------- 16.13 MiB/191.25 MiB
# ⠦ Preparing packages... (0/1)------------------- 16.38 MiB/191.25 MiB
# ⠦ Preparing packages... (0/1)------------------- 16.57 MiB/191.25 MiB
# ⠦ Preparing packages... (0/1)------------------- 16.71 MiB/191.25 MiB
# ⠦ Preparing packages... (0/1)------------------- 16.73 MiB/191.25 MiB
# ⠧ Preparing packages... (0/1)------------------- 16.82 MiB/191.25 MiB
# ⠧ Preparing packages... (0/1)------------------- 16.96 MiB/191.25 MiB
# ⠧ Preparing packages... (0/1)------------------- 17.15 MiB/191.25 MiB
# ⠧ Preparing packages... (0/1)------------------- 17.35 MiB/191.25 MiB
# ⠇ Preparing packages... (0/1)------------------- 17.54 MiB/191.25 MiB
# ⠇ Preparing packages... (0/1)------------------- 17.74 MiB/191.25 MiB
# ⠇ Preparing packages... (0/1)------------------- 17.95 MiB/191.25 MiB
# ⠇ Preparing packages... (0/1)------------------- 18.12 MiB/191.25 MiB
# ⠋ Preparing packages... (0/1)------------------- 18.35 MiB/191.25 MiB
# ⠋ Preparing packages... (0/1)------------------- 18.38 MiB/191.25 MiB
# ⠋ Preparing packages... (0/1)------------------- 18.47 MiB/191.25 MiB
# ⠋ Preparing packages... (0/1)------------------- 18.60 MiB/191.25 MiB
# ⠙ Preparing packages... (0/1)------------------- 18.76 MiB/191.25 MiB
# ⠙ Preparing packages... (0/1)------------------- 18.90 MiB/191.25 MiB
# ⠙ Preparing packages... (0/1)------------------- 19.08 MiB/191.25 MiB
# ⠙ Preparing packages... (0/1)------------------- 19.30 MiB/191.25 MiB
# ⠙ Preparing packages... (0/1)------------------- 19.46 MiB/191.25 MiB
# ⠹ Preparing packages... (0/1)------------------- 19.64 MiB/191.25 MiB
# ⠹ Preparing packages... (0/1)------------------- 19.83 MiB/191.25 MiB
# ⠹ Preparing packages... (0/1)------------------- 20.00 MiB/191.25 MiB
# ⠸ Preparing packages... (0/1)------------------- 20.02 MiB/191.25 MiB
# ⠸ Preparing packages... (0/1)------------------- 20.07 MiB/191.25 MiB
# ⠸ Preparing packages... (0/1)------------------- 20.25 MiB/191.25 MiB
# ⠸ Preparing packages... (0/1)------------------- 20.46 MiB/191.25 MiB
# ⠸ Preparing packages... (0/1)------------------- 20.66 MiB/191.25 MiB
# ⠼ Preparing packages... (0/1)------------------- 20.88 MiB/191.25 MiB
# ⠼ Preparing packages... (0/1)------------------- 21.08 MiB/191.25 MiB
# ⠼ Preparing packages... (0/1)------------------- 21.32 MiB/191.25 MiB
# ⠼ Preparing packages... (0/1)------------------- 21.50 MiB/191.25 MiB
# ⠴ Preparing packages... (0/1)------------------- 21.71 MiB/191.25 MiB
# ⠴ Preparing packages... (0/1)------------------- 21.75 MiB/191.25 MiB
# ⠴ Preparing packages... (0/1)------------------- 21.76 MiB/191.25 MiB
# ⠴ Preparing packages... (0/1)------------------- 21.90 MiB/191.25 MiB
# ⠦ Preparing packages... (0/1)------------------- 22.08 MiB/191.25 MiB
# ⠦ Preparing packages... (0/1)------------------- 22.29 MiB/191.25 MiB
# ⠦ Preparing packages... (0/1)------------------- 22.50 MiB/191.25 MiB
# ⠦ Preparing packages... (0/1)------------------- 22.69 MiB/191.25 MiB
# ⠧ Preparing packages... (0/1)------------------- 22.89 MiB/191.25 MiB
# ⠧ Preparing packages... (0/1)------------------- 23.11 MiB/191.25 MiB
# ⠇ Preparing packages... (0/1)------------------- 23.39 MiB/191.25 MiB
# ⠇ Preparing packages... (0/1)------------------- 23.43 MiB/191.25 MiB
# ⠇ Preparing packages... (0/1)------------------- 23.45 MiB/191.25 MiB
# ⠇ Preparing packages... (0/1)------------------- 23.58 MiB/191.25 MiB
# ⠇ Preparing packages... (0/1)------------------- 23.78 MiB/191.25 MiB
# ⠇ Preparing packages... (0/1)------------------- 23.98 MiB/191.25 MiB
# ⠋ Preparing packages... (0/1)------------------- 24.17 MiB/191.25 MiB
# ⠋ Preparing packages... (0/1)------------------- 24.37 MiB/191.25 MiB
# ⠋ Preparing packages... (0/1)------------------- 24.54 MiB/191.25 MiB
# ⠋ Preparing packages... (0/1)------------------- 24.75 MiB/191.25 MiB
# ⠙ Preparing packages... (0/1)------------------- 24.92 MiB/191.25 MiB
# ⠙ Preparing packages... (0/1)------------------- 25.14 MiB/191.25 MiB
# ⠙ Preparing packages... (0/1)------------------- 25.16 MiB/191.25 MiB
# ⠙ Preparing packages... (0/1)------------------- 25.23 MiB/191.25 MiB
# ⠹ Preparing packages... (0/1)------------------- 25.34 MiB/191.25 MiB
# ⠹ Preparing packages... (0/1)------------------- 25.52 MiB/191.25 MiB
# ⠹ Preparing packages... (0/1)------------------- 25.71 MiB/191.25 MiB
# ⠹ Preparing packages... (0/1)------------------- 25.94 MiB/191.25 MiB
# ⠸ Preparing packages... (0/1)------------------- 26.05 MiB/191.25 MiB
# ⠸ Preparing packages... (0/1)------------------- 26.27 MiB/191.25 MiB
# ⠸ Preparing packages... (0/1)------------------- 26.47 MiB/191.25 MiB
# ⠼ Preparing packages... (0/1)------------------- 26.70 MiB/191.25 MiB
# ⠼ Preparing packages... (0/1)------------------- 26.81 MiB/191.25 MiB
# ⠼ Preparing packages... (0/1)------------------- 26.82 MiB/191.25 MiB
# ⠼ Preparing packages... (0/1)------------------- 26.96 MiB/191.25 MiB
# ⠼ Preparing packages... (0/1)------------------- 27.16 MiB/191.25 MiB
# ⠴ Preparing packages... (0/1)------------------- 27.30 MiB/191.25 MiB
# ⠴ Preparing packages... (0/1)------------------- 27.46 MiB/191.25 MiB
# ⠴ Preparing packages... (0/1)------------------- 27.62 MiB/191.25 MiB
# ⠴ Preparing packages... (0/1)------------------- 27.81 MiB/191.25 MiB
# ⠦ Preparing packages... (0/1)------------------- 27.95 MiB/191.25 MiB
# ⠦ Preparing packages... (0/1)------------------- 28.14 MiB/191.25 MiB
# ⠦ Preparing packages... (0/1)------------------- 28.28 MiB/191.25 MiB
# ⠦ Preparing packages... (0/1)------------------- 28.30 MiB/191.25 MiB
# ⠧ Preparing packages... (0/1)------------------- 28.34 MiB/191.25 MiB
# ⠧ Preparing packages... (0/1)------------------- 28.50 MiB/191.25 MiB
# ⠧ Preparing packages... (0/1)------------------- 28.68 MiB/191.25 MiB
# ⠧ Preparing packages... (0/1)------------------- 28.88 MiB/191.25 MiB
# ⠇ Preparing packages... (0/1)------------------- 29.08 MiB/191.25 MiB
# ⠇ Preparing packages... (0/1)------------------- 29.20 MiB/191.25 MiB
# ⠇ Preparing packages... (0/1)------------------- 29.45 MiB/191.25 MiB
# ⠇ Preparing packages... (0/1)------------------- 29.63 MiB/191.25 MiB
# ⠋ Preparing packages... (0/1)------------------- 29.81 MiB/191.25 MiB
# ⠋ Preparing packages... (0/1)------------------- 29.92 MiB/191.25 MiB
# ⠋ Preparing packages... (0/1)------------------- 29.93 MiB/191.25 MiB
# ⠋ Preparing packages... (0/1)------------------- 30.05 MiB/191.25 MiB
# ⠋ Preparing packages... (0/1)------------------- 30.20 MiB/191.25 MiB
# ⠙ Preparing packages... (0/1)------------------- 30.42 MiB/191.25 MiB
# ⠙ Preparing packages... (0/1)------------------- 30.57 MiB/191.25 MiB
# ⠙ Preparing packages... (0/1)------------------- 30.78 MiB/191.25 MiB
# ⠙ Preparing packages... (0/1)------------------- 30.98 MiB/191.25 MiB
# ⠹ Preparing packages... (0/1)------------------- 31.20 MiB/191.25 MiB
# ⠹ Preparing packages... (0/1)------------------- 31.45 MiB/191.25 MiB
# ⠹ Preparing packages... (0/1)------------------- 31.67 MiB/191.25 MiB
# ⠹ Preparing packages... (0/1)------------------- 31.70 MiB/191.25 MiB
# ⠸ Preparing packages... (0/1)------------------- 31.78 MiB/191.25 MiB
# ⠸ Preparing packages... (0/1)------------------- 31.96 MiB/191.25 MiB
# ⠸ Preparing packages... (0/1)------------------- 32.20 MiB/191.25 MiB
# ⠸ Preparing packages... (0/1)------------------- 32.45 MiB/191.25 MiB
# ⠼ Preparing packages... (0/1)------------------- 32.70 MiB/191.25 MiB
# ⠼ Preparing packages... (0/1)------------------- 32.94 MiB/191.25 MiB
# ⠼ Preparing packages... (0/1)------------------- 33.10 MiB/191.25 MiB
# ⠼ Preparing packages... (0/1)------------------- 33.42 MiB/191.25 MiB
# ⠴ Preparing packages... (0/1)------------------- 33.61 MiB/191.25 MiB
# ⠴ Preparing packages... (0/1)------------------- 33.71 MiB/191.25 MiB
# ⠴ Preparing packages... (0/1)------------------- 33.72 MiB/191.25 MiB
# ⠴ Preparing packages... (0/1)------------------- 33.80 MiB/191.25 MiB
# ⠦ Preparing packages... (0/1)------------------- 33.98 MiB/191.25 MiB
# ⠦ Preparing packages... (0/1)------------------- 34.17 MiB/191.25 MiB
# ⠦ Preparing packages... (0/1)------------------- 34.35 MiB/191.25 MiB
# ⠦ Preparing packages... (0/1)------------------- 34.57 MiB/191.25 MiB
# ⠧ Preparing packages... (0/1)------------------- 34.76 MiB/191.25 MiB
# ⠧ Preparing packages... (0/1)------------------- 34.97 MiB/191.25 MiB
# ⠧ Preparing packages... (0/1)------------------- 35.19 MiB/191.25 MiB
# ⠇ Preparing packages... (0/1)------------------- 35.35 MiB/191.25 MiB
# ⠇ Preparing packages... (0/1)------------------- 35.36 MiB/191.25 MiB
# ⠇ Preparing packages... (0/1)------------------- 35.44 MiB/191.25 MiB
# ⠇ Preparing packages... (0/1)------------------- 35.57 MiB/191.25 MiB
# ⠇ Preparing packages... (0/1)------------------- 35.75 MiB/191.25 MiB
# ⠋ Preparing packages... (0/1)------------------- 35.99 MiB/191.25 MiB
# ⠋ Preparing packages... (0/1)------------------- 36.14 MiB/191.25 MiB
# ⠋ Preparing packages... (0/1)------------------- 36.36 MiB/191.25 MiB
# ⠋ Preparing packages... (0/1)------------------- 36.60 MiB/191.25 MiB
# ⠙ Preparing packages... (0/1)------------------- 36.74 MiB/191.25 MiB
# ⠙ Preparing packages... (0/1)------------------- 37.00 MiB/191.25 MiB
# ⠙ Preparing packages... (0/1)------------------- 37.14 MiB/191.25 MiB
# ⠙ Preparing packages... (0/1)------------------- 37.16 MiB/191.25 MiB
# ⠹ Preparing packages... (0/1)------------------- 37.27 MiB/191.25 MiB
# ⠹ Preparing packages... (0/1)------------------- 37.50 MiB/191.25 MiB
# ⠹ Preparing packages... (0/1)------------------- 37.77 MiB/191.25 MiB
# ⠹ Preparing packages... (0/1)------------------- 38.02 MiB/191.25 MiB
# ⠸ Preparing packages... (0/1)------------------- 38.25 MiB/191.25 MiB
# ⠸ Preparing packages... (0/1)------------------- 38.47 MiB/191.25 MiB
# ⠸ Preparing packages... (0/1)------------------- 38.69 MiB/191.25 MiB
# ⠼ Preparing packages... (0/1)------------------- 38.94 MiB/191.25 MiB
# ⠼ Preparing packages... (0/1)------------------- 39.20 MiB/191.25 MiB
# ⠼ Preparing packages... (0/1)------------------- 39.22 MiB/191.25 MiB
# ⠼ Preparing packages... (0/1)------------------- 39.32 MiB/191.25 MiB
# ⠼ Preparing packages... (0/1)------------------- 39.48 MiB/191.25 MiB
# ⠼ Preparing packages... (0/1)------------------- 39.67 MiB/191.25 MiB
# ⠴ Preparing packages... (0/1)------------------- 39.88 MiB/191.25 MiB
# ⠴ Preparing packages... (0/1)------------------- 40.05 MiB/191.25 MiB
# ⠴ Preparing packages... (0/1)------------------- 40.29 MiB/191.25 MiB
# ⠴ Preparing packages... (0/1)------------------- 40.50 MiB/191.25 MiB
# ⠦ Preparing packages... (0/1)------------------- 40.66 MiB/191.25 MiB
# ⠦ Preparing packages... (0/1)------------------- 40.88 MiB/191.25 MiB
# ⠦ Preparing packages... (0/1)------------------- 41.02 MiB/191.25 MiB
# ⠦ Preparing packages... (0/1)------------------- 41.03 MiB/191.25 MiB
# ⠧ Preparing packages... (0/1)------------------- 41.17 MiB/191.25 MiB
# ⠧ Preparing packages... (0/1)------------------- 41.38 MiB/191.25 MiB
# ⠧ Preparing packages... (0/1)------------------- 41.60 MiB/191.25 MiB
# ⠧ Preparing packages... (0/1)------------------- 41.78 MiB/191.25 MiB
# ⠇ Preparing packages... (0/1)------------------- 41.98 MiB/191.25 MiB
# ⠇ Preparing packages... (0/1)------------------- 42.20 MiB/191.25 MiB
# ⠇ Preparing packages... (0/1)------------------- 42.39 MiB/191.25 MiB
# ⠋ Preparing packages... (0/1)------------------- 42.58 MiB/191.25 MiB
# ⠋ Preparing packages... (0/1)------------------- 42.79 MiB/191.25 MiB
# ⠋ Preparing packages... (0/1)------------------- 42.81 MiB/191.25 MiB
# ⠋ Preparing packages... (0/1)------------------- 42.89 MiB/191.25 MiB
# ⠋ Preparing packages... (0/1)------------------- 43.03 MiB/191.25 MiB
# ⠙ Preparing packages... (0/1)------------------- 43.20 MiB/191.25 MiB
# ⠙ Preparing packages... (0/1)------------------- 43.38 MiB/191.25 MiB
# ⠙ Preparing packages... (0/1)------------------- 43.57 MiB/191.25 MiB
# ⠙ Preparing packages... (0/1)------------------- 43.75 MiB/191.25 MiB
# ⠹ Preparing packages... (0/1)------------------- 43.99 MiB/191.25 MiB
# ⠹ Preparing packages... (0/1)------------------- 44.17 MiB/191.25 MiB
# ⠹ Preparing packages... (0/1)------------------- 44.36 MiB/191.25 MiB
# ⠹ Preparing packages... (0/1)------------------- 44.47 MiB/191.25 MiB
# ⠸ Preparing packages... (0/1)------------------- 44.48 MiB/191.25 MiB
# ⠸ Preparing packages... (0/1)------------------- 44.64 MiB/191.25 MiB
# ⠸ Preparing packages... (0/1)------------------- 44.79 MiB/191.25 MiB
# ⠸ Preparing packages... (0/1)------------------- 45.02 MiB/191.25 MiB
# ⠼ Preparing packages... (0/1)------------------- 45.20 MiB/191.25 MiB
# ⠼ Preparing packages... (0/1)------------------- 45.41 MiB/191.25 MiB
# ⠼ Preparing packages... (0/1)------------------- 45.59 MiB/191.25 MiB
# ⠼ Preparing packages... (0/1)------------------- 45.81 MiB/191.25 MiB
# ⠴ Preparing packages... (0/1)------------------- 45.98 MiB/191.25 MiB
# ⠴ Preparing packages... (0/1)------------------- 46.20 MiB/191.25 MiB
# ⠴ Preparing packages... (0/1)------------------- 46.22 MiB/191.25 MiB
# ⠴ Preparing packages... (0/1)------------------- 46.29 MiB/191.25 MiB
# ⠴ Preparing packages... (0/1)------------------- 46.45 MiB/191.25 MiB
# ⠦ Preparing packages... (0/1)------------------- 46.69 MiB/191.25 MiB
# ⠦ Preparing packages... (0/1)------------------- 46.89 MiB/191.25 MiB
# ⠦ Preparing packages... (0/1)------------------- 47.16 MiB/191.25 MiB
# ⠦ Preparing packages... (0/1)------------------- 47.38 MiB/191.25 MiB
# ⠧ Preparing packages... (0/1)------------------- 47.59 MiB/191.25 MiB
# ⠧ Preparing packages... (0/1)------------------- 47.82 MiB/191.25 MiB
# ⠧ Preparing packages... (0/1)------------------- 48.04 MiB/191.25 MiB
# ⠧ Preparing packages... (0/1)------------------- 48.13 MiB/191.25 MiB
# ⠇ Preparing packages... (0/1)------------------- 48.15 MiB/191.25 MiB
# ⠇ Preparing packages... (0/1)------------------- 48.25 MiB/191.25 MiB
# ⠇ Preparing packages... (0/1)------------------- 48.52 MiB/191.25 MiB
# ⠇ Preparing packages... (0/1)------------------- 48.69 MiB/191.25 MiB
# ⠋ Preparing packages... (0/1)------------------- 48.85 MiB/191.25 MiB
# ⠋ Preparing packages... (0/1)------------------- 49.08 MiB/191.25 MiB
# ⠋ Preparing packages... (0/1)------------------- 49.23 MiB/191.25 MiB
# ⠋ Preparing packages... (0/1)------------------- 49.43 MiB/191.25 MiB
# ⠙ Preparing packages... (0/1)------------------- 49.62 MiB/191.25 MiB
# ⠙ Preparing packages... (0/1)------------------- 49.78 MiB/191.25 MiB
# ⠙ Preparing packages... (0/1)------------------- 49.80 MiB/191.25 MiB
# ⠙ Preparing packages... (0/1)------------------- 49.87 MiB/191.25 MiB
# ⠹ Preparing packages... (0/1)------------------- 50.03 MiB/191.25 MiB
# ⠹ Preparing packages... (0/1)------------------- 50.23 MiB/191.25 MiB
# ⠹ Preparing packages... (0/1)------------------- 50.44 MiB/191.25 MiB
# ⠹ Preparing packages... (0/1)------------------- 50.62 MiB/191.25 MiB
# ⠸ Preparing packages... (0/1)------------------- 50.84 MiB/191.25 MiB
# ⠸ Preparing packages... (0/1)------------------- 51.08 MiB/191.25 MiB
# ⠸ Preparing packages... (0/1)------------------- 51.22 MiB/191.25 MiB
# ⠼ Preparing packages... (0/1)------------------- 51.43 MiB/191.25 MiB
# ⠼ Preparing packages... (0/1)------------------- 51.50 MiB/191.25 MiB
# ⠼ Preparing packages... (0/1)------------------- 51.52 MiB/191.25 MiB
# ⠼ Preparing packages... (0/1)------------------- 51.61 MiB/191.25 MiB
# ⠼ Preparing packages... (0/1)------------------- 51.86 MiB/191.25 MiB
# ⠴ Preparing packages... (0/1)------------------- 52.02 MiB/191.25 MiB
# ⠴ Preparing packages... (0/1)------------------- 52.19 MiB/191.25 MiB
# ⠴ Preparing packages... (0/1)------------------- 52.33 MiB/191.25 MiB
# ⠦ Preparing packages... (0/1)------------------- 52.48 MiB/191.25 MiB
# ⠦ Preparing packages... (0/1)------------------- 52.59 MiB/191.25 MiB
# ⠦ Preparing packages... (0/1)------------------- 52.67 MiB/191.25 MiB
# ⠦ Preparing packages... (0/1)------------------- 52.83 MiB/191.25 MiB
# ⠧ Preparing packages... (0/1)------------------- 52.84 MiB/191.25 MiB
# ⠧ Preparing packages... (0/1)------------------- 52.87 MiB/191.25 MiB
# ⠧ Preparing packages... (0/1)------------------- 52.92 MiB/191.25 MiB
# ⠧ Preparing packages... (0/1)------------------- 53.08 MiB/191.25 MiB
# ⠧ Preparing packages... (0/1)------------------- 53.22 MiB/191.25 MiB
# ⠇ Preparing packages... (0/1)------------------- 53.42 MiB/191.25 MiB
# ⠇ Preparing packages... (0/1)------------------- 53.63 MiB/191.25 MiB
# ⠇ Preparing packages... (0/1)------------------- 53.78 MiB/191.25 MiB
# ⠇ Preparing packages... (0/1)------------------- 54.01 MiB/191.25 MiB
# ⠋ Preparing packages... (0/1)------------------- 54.26 MiB/191.25 MiB
# ⠋ Preparing packages... (0/1)------------------- 54.29 MiB/191.25 MiB
# ⠋ Preparing packages... (0/1)------------------- 54.31 MiB/191.25 MiB
# ⠋ Preparing packages... (0/1)------------------- 54.48 MiB/191.25 MiB
# ⠙ Preparing packages... (0/1)------------------- 54.66 MiB/191.25 MiB
# ⠙ Preparing packages... (0/1)------------------- 54.89 MiB/191.25 MiB
# ⠙ Preparing packages... (0/1)------------------- 55.14 MiB/191.25 MiB
# ⠙ Preparing packages... (0/1)------------------- 55.39 MiB/191.25 MiB
# ⠹ Preparing packages... (0/1)------------------- 55.59 MiB/191.25 MiB
# ⠹ Preparing packages... (0/1)------------------- 55.85 MiB/191.25 MiB
# ⠹ Preparing packages... (0/1)------------------- 56.08 MiB/191.25 MiB
# ⠹ Preparing packages... (0/1)------------------- 56.27 MiB/191.25 MiB
# ⠸ Preparing packages... (0/1)------------------- 56.29 MiB/191.25 MiB
# ⠸ Preparing packages... (0/1)------------------- 56.36 MiB/191.25 MiB
# ⠸ Preparing packages... (0/1)------------------- 56.51 MiB/191.25 MiB
# ⠸ Preparing packages... (0/1)------------------- 56.68 MiB/191.25 MiB
# ⠸ Preparing packages... (0/1)------------------- 56.80 MiB/191.25 MiB
# ⠼ Preparing packages... (0/1)------------------- 56.94 MiB/191.25 MiB
# ⠼ Preparing packages... (0/1)------------------- 57.14 MiB/191.25 MiB
# ⠼ Preparing packages... (0/1)------------------- 57.30 MiB/191.25 MiB
# ⠼ Preparing packages... (0/1)------------------- 57.47 MiB/191.25 MiB
# ⠴ Preparing packages... (0/1)------------------- 57.63 MiB/191.25 MiB
# ⠴ Preparing packages... (0/1)------------------- 57.69 MiB/191.25 MiB
# ⠴ Preparing packages... (0/1)------------------- 57.71 MiB/191.25 MiB
# ⠴ Preparing packages... (0/1)------------------- 57.86 MiB/191.25 MiB
# ⠦ Preparing packages... (0/1)------------------- 58.05 MiB/191.25 MiB
# ⠦ Preparing packages... (0/1)------------------- 58.26 MiB/191.25 MiB
# ⠦ Preparing packages... (0/1)------------------- 58.46 MiB/191.25 MiB
# ⠦ Preparing packages... (0/1)------------------- 58.64 MiB/191.25 MiB
# ⠧ Preparing packages... (0/1)------------------- 58.83 MiB/191.25 MiB
# ⠧ Preparing packages... (0/1)------------------- 59.03 MiB/191.25 MiB
# ⠇ Preparing packages... (0/1)------------------- 59.23 MiB/191.25 MiB
# ⠇ Preparing packages... (0/1)------------------- 59.40 MiB/191.25 MiB
# ⠇ Preparing packages... (0/1)------------------- 59.42 MiB/191.25 MiB
# ⠇ Preparing packages... (0/1)------------------- 59.50 MiB/191.25 MiB
# ⠇ Preparing packages... (0/1)------------------- 59.66 MiB/191.25 MiB
# ⠇ Preparing packages... (0/1)------------------- 59.83 MiB/191.25 MiB
# ⠋ Preparing packages... (0/1)------------------- 60.07 MiB/191.25 MiB
# ⠋ Preparing packages... (0/1)------------------- 60.28 MiB/191.25 MiB
# ⠋ Preparing packages... (0/1)------------------- 60.47 MiB/191.25 MiB
# ⠋ Preparing packages... (0/1)------------------- 60.69 MiB/191.25 MiB
# ⠙ Preparing packages... (0/1)------------------- 60.85 MiB/191.25 MiB
# ⠙ Preparing packages... (0/1)------------------- 61.14 MiB/191.25 MiB
# ⠙ Preparing packages... (0/1)------------------- 61.20 MiB/191.25 MiB
# ⠙ Preparing packages... (0/1)------------------- 61.22 MiB/191.25 MiB
# ⠹ Preparing packages... (0/1)------------------- 61.32 MiB/191.25 MiB
# ⠹ Preparing packages... (0/1)------------------- 61.54 MiB/191.25 MiB
# ⠹ Preparing packages... (0/1)------------------- 61.70 MiB/191.25 MiB
# ⠹ Preparing packages... (0/1)------------------- 61.88 MiB/191.25 MiB
# ⠸ Preparing packages... (0/1)------------------- 62.08 MiB/191.25 MiB
# ⠸ Preparing packages... (0/1)------------------- 62.26 MiB/191.25 MiB
# ⠸ Preparing packages... (0/1)------------------- 62.46 MiB/191.25 MiB
# ⠼ Preparing packages... (0/1)------------------- 62.64 MiB/191.25 MiB
# ⠼ Preparing packages... (0/1)------------------- 62.79 MiB/191.25 MiB
# ⠼ Preparing packages... (0/1)------------------- 62.81 MiB/191.25 MiB
# ⠼ Preparing packages... (0/1)------------------- 62.89 MiB/191.25 MiB
# ⠼ Preparing packages... (0/1)------------------- 63.02 MiB/191.25 MiB
# ⠴ Preparing packages... (0/1)------------------- 63.14 MiB/191.25 MiB
# ⠴ Preparing packages... (0/1)------------------- 63.29 MiB/191.25 MiB
# ⠴ Preparing packages... (0/1)------------------- 63.50 MiB/191.25 MiB
# ⠴ Preparing packages... (0/1)------------------- 63.72 MiB/191.25 MiB
# ⠦ Preparing packages... (0/1)------------------- 63.93 MiB/191.25 MiB
# ⠦ Preparing packages... (0/1)------------------- 64.09 MiB/191.25 MiB
# ⠦ Preparing packages... (0/1)------------------- 64.28 MiB/191.25 MiB
# ⠦ Preparing packages... (0/1)------------------- 64.36 MiB/191.25 MiB
# ⠧ Preparing packages... (0/1)------------------- 64.38 MiB/191.25 MiB
# ⠧ Preparing packages... (0/1)------------------- 64.47 MiB/191.25 MiB
# ⠧ Preparing packages... (0/1)------------------- 64.70 MiB/191.25 MiB
# ⠧ Preparing packages... (0/1)------------------- 64.84 MiB/191.25 MiB
# ⠇ Preparing packages... (0/1)------------------- 65.02 MiB/191.25 MiB
# ⠇ Preparing packages... (0/1)------------------- 65.18 MiB/191.25 MiB
# ⠇ Preparing packages... (0/1)------------------- 65.37 MiB/191.25 MiB
# ⠇ Preparing packages... (0/1)------------------- 65.54 MiB/191.25 MiB
# ⠋ Preparing packages... (0/1)------------------- 65.73 MiB/191.25 MiB
# ⠋ Preparing packages... (0/1)------------------- 65.86 MiB/191.25 MiB
# ⠋ Preparing packages... (0/1)------------------- 65.87 MiB/191.25 MiB
# ⠋ Preparing packages... (0/1)------------------- 66.02 MiB/191.25 MiB
# ⠋ Preparing packages... (0/1)------------------- 66.18 MiB/191.25 MiB
# ⠙ Preparing packages... (0/1)------------------- 66.34 MiB/191.25 MiB
# ⠙ Preparing packages... (0/1)------------------- 66.53 MiB/191.25 MiB
# ⠙ Preparing packages... (0/1)------------------- 66.67 MiB/191.25 MiB
# ⠙ Preparing packages... (0/1)------------------- 66.86 MiB/191.25 MiB
# ⠹ Preparing packages... (0/1)------------------- 67.03 MiB/191.25 MiB
# ⠹ Preparing packages... (0/1)------------------- 67.24 MiB/191.25 MiB
# ⠹ Preparing packages... (0/1)------------------- 67.45 MiB/191.25 MiB
# ⠹ Preparing packages... (0/1)------------------- 67.50 MiB/191.25 MiB
# ⠸ Preparing packages... (0/1)------------------- 67.52 MiB/191.25 MiB
# ⠸ Preparing packages... (0/1)------------------- 67.69 MiB/191.25 MiB
# ⠸ Preparing packages... (0/1)------------------- 67.88 MiB/191.25 MiB
# ⠸ Preparing packages... (0/1)------------------- 68.07 MiB/191.25 MiB
# ⠼ Preparing packages... (0/1)------------------- 68.23 MiB/191.25 MiB
# ⠼ Preparing packages... (0/1)------------------- 68.39 MiB/191.25 MiB
# ⠼ Preparing packages... (0/1)------------------- 68.57 MiB/191.25 MiB
# ⠼ Preparing packages... (0/1)------------------- 68.73 MiB/191.25 MiB
# ⠴ Preparing packages... (0/1)------------------- 68.88 MiB/191.25 MiB
# ⠴ Preparing packages... (0/1)------------------- 68.94 MiB/191.25 MiB
# ⠴ Preparing packages... (0/1)------------------- 68.95 MiB/191.25 MiB
# ⠴ Preparing packages... (0/1)------------------- 69.06 MiB/191.25 MiB
# ⠦ Preparing packages... (0/1)------------------- 69.20 MiB/191.25 MiB
# ⠦ Preparing packages... (0/1)------------------- 69.39 MiB/191.25 MiB
# ⠦ Preparing packages... (0/1)------------------- 69.59 MiB/191.25 MiB
# ⠦ Preparing packages... (0/1)------------------- 69.80 MiB/191.25 MiB
# ⠧ Preparing packages... (0/1)------------------- 69.97 MiB/191.25 MiB
# ⠧ Preparing packages... (0/1)------------------- 70.14 MiB/191.25 MiB
# ⠧ Preparing packages... (0/1)------------------- 70.33 MiB/191.25 MiB
# ⠇ Preparing packages... (0/1)------------------- 70.56 MiB/191.25 MiB
# ⠇ Preparing packages... (0/1)------------------- 70.59 MiB/191.25 MiB
# ⠇ Preparing packages... (0/1)------------------- 70.61 MiB/191.25 MiB
# ⠇ Preparing packages... (0/1)------------------- 70.76 MiB/191.25 MiB
# ⠇ Preparing packages... (0/1)------------------- 70.92 MiB/191.25 MiB
# ⠋ Preparing packages... (0/1)------------------- 71.11 MiB/191.25 MiB
# ⠋ Preparing packages... (0/1)------------------- 71.34 MiB/191.25 MiB
# ⠋ Preparing packages... (0/1)------------------- 71.55 MiB/191.25 MiB
# ⠋ Preparing packages... (0/1)------------------- 71.72 MiB/191.25 MiB
# ⠙ Preparing packages... (0/1)------------------- 71.92 MiB/191.25 MiB
# ⠙ Preparing packages... (0/1)------------------- 72.17 MiB/191.25 MiB
# ⠙ Preparing packages... (0/1)------------------- 72.32 MiB/191.25 MiB
# ⠙ Preparing packages... (0/1)------------------- 72.34 MiB/191.25 MiB
# ⠹ Preparing packages... (0/1)------------------- 72.40 MiB/191.25 MiB
# ⠹ Preparing packages... (0/1)------------------- 72.58 MiB/191.25 MiB
# ⠹ Preparing packages... (0/1)------------------- 72.75 MiB/191.25 MiB
# ⠹ Preparing packages... (0/1)------------------- 72.92 MiB/191.25 MiB
# ⠸ Preparing packages... (0/1)------------------- 73.03 MiB/191.25 MiB
# ⠸ Preparing packages... (0/1)------------------- 73.20 MiB/191.25 MiB
# ⠸ Preparing packages... (0/1)------------------- 73.35 MiB/191.25 MiB
# ⠸ Preparing packages... (0/1)------------------- 73.48 MiB/191.25 MiB
# ⠼ Preparing packages... (0/1)------------------- 73.67 MiB/191.25 MiB
# ⠼ Preparing packages... (0/1)------------------- 73.67 MiB/191.25 MiB
# ⠼ Preparing packages... (0/1)------------------- 73.74 MiB/191.25 MiB
# ⠼ Preparing packages... (0/1)------------------- 73.84 MiB/191.25 MiB
# ⠼ Preparing packages... (0/1)------------------- 73.98 MiB/191.25 MiB
# ⠴ Preparing packages... (0/1)------------------- 74.06 MiB/191.25 MiB
# ⠴ Preparing packages... (0/1)------------------- 74.22 MiB/191.25 MiB
# ⠴ Preparing packages... (0/1)------------------- 74.32 MiB/191.25 MiB
# ⠴ Preparing packages... (0/1)------------------- 74.47 MiB/191.25 MiB
# ⠦ Preparing packages... (0/1)------------------- 74.59 MiB/191.25 MiB
# ⠦ Preparing packages... (0/1)------------------- 74.72 MiB/191.25 MiB
# ⠦ Preparing packages... (0/1)------------------- 74.86 MiB/191.25 MiB
# ⠦ Preparing packages... (0/1)------------------- 74.87 MiB/191.25 MiB
# ⠧ Preparing packages... (0/1)------------------- 74.95 MiB/191.25 MiB
# ⠧ Preparing packages... (0/1)------------------- 75.05 MiB/191.25 MiB
# ⠧ Preparing packages... (0/1)------------------- 75.17 MiB/191.25 MiB
# ⠧ Preparing packages... (0/1)------------------- 75.33 MiB/191.25 MiB
# ⠇ Preparing packages... (0/1)------------------- 75.52 MiB/191.25 MiB
# ⠇ Preparing packages... (0/1)------------------- 75.66 MiB/191.25 MiB
# ⠇ Preparing packages... (0/1)------------------- 75.83 MiB/191.25 MiB
# ⠇ Preparing packages... (0/1)------------------- 75.98 MiB/191.25 MiB
# ⠋ Preparing packages... (0/1)------------------- 76.17 MiB/191.25 MiB
# ⠋ Preparing packages... (0/1)------------------- 76.19 MiB/191.25 MiB
# ⠋ Preparing packages... (0/1)------------------- 76.20 MiB/191.25 MiB
# ⠋ Preparing packages... (0/1)------------------- 76.36 MiB/191.25 MiB
# ⠙ Preparing packages... (0/1)m------------------ 76.51 MiB/191.25 MiB
# ⠙ Preparing packages... (0/1)m------------------ 76.65 MiB/191.25 MiB
# ⠙ Preparing packages... (0/1)m------------------ 76.81 MiB/191.25 MiB
# ⠙ Preparing packages... (0/1)m------------------ 77.03 MiB/191.25 MiB
# ⠹ Preparing packages... (0/1)m------------------ 77.22 MiB/191.25 MiB
# ⠹ Preparing packages... (0/1)m------------------ 77.39 MiB/191.25 MiB
# ⠹ Preparing packages... (0/1)m------------------ 77.58 MiB/191.25 MiB
# ⠹ Preparing packages... (0/1)m------------------ 77.67 MiB/191.25 MiB
# ⠸ Preparing packages... (0/1)m------------------ 77.69 MiB/191.25 MiB
# ⠸ Preparing packages... (0/1)m------------------ 77.77 MiB/191.25 MiB
# ⠸ Preparing packages... (0/1)m------------------ 77.92 MiB/191.25 MiB
# ⠸ Preparing packages... (0/1)m------------------ 78.09 MiB/191.25 MiB
# ⠼ Preparing packages... (0/1)m------------------ 78.26 MiB/191.25 MiB
# ⠼ Preparing packages... (0/1)m------------------ 78.42 MiB/191.25 MiB
# ⠼ Preparing packages... (0/1)m------------------ 78.57 MiB/191.25 MiB
# ⠼ Preparing packages... (0/1)m------------------ 78.75 MiB/191.25 MiB
# ⠴ Preparing packages... (0/1)m------------------ 78.91 MiB/191.25 MiB
# ⠴ Preparing packages... (0/1)m------------------ 79.06 MiB/191.25 MiB
# ⠴ Preparing packages... (0/1)m------------------ 79.08 MiB/191.25 MiB
# ⠴ Preparing packages... (0/1)m------------------ 79.14 MiB/191.25 MiB
# ⠦ Preparing packages... (0/1)m------------------ 79.31 MiB/191.25 MiB
# ⠦ Preparing packages... (0/1)m------------------ 79.47 MiB/191.25 MiB
# ⠦ Preparing packages... (0/1)m------------------ 79.69 MiB/191.25 MiB
# ⠦ Preparing packages... (0/1)m------------------ 79.91 MiB/191.25 MiB
# ⠧ Preparing packages... (0/1)m------------------ 80.11 MiB/191.25 MiB
# ⠧ Preparing packages... (0/1)m------------------ 80.33 MiB/191.25 MiB
# ⠧ Preparing packages... (0/1)m------------------ 80.50 MiB/191.25 MiB
# ⠇ Preparing packages... (0/1)m------------------ 80.69 MiB/191.25 MiB
# ⠇ Preparing packages... (0/1)m------------------ 80.79 MiB/191.25 MiB
# ⠇ Preparing packages... (0/1)m------------------ 80.81 MiB/191.25 MiB
# ⠇ Preparing packages... (0/1)m------------------ 80.94 MiB/191.25 MiB
# ⠇ Preparing packages... (0/1)m------------------ 81.09 MiB/191.25 MiB
# ⠋ Preparing packages... (0/1)m------------------ 81.28 MiB/191.25 MiB
# ⠋ Preparing packages... (0/1)m------------------ 81.54 MiB/191.25 MiB
# ⠋ Preparing packages... (0/1)m------------------ 81.76 MiB/191.25 MiB
# ⠋ Preparing packages... (0/1)m------------------ 81.95 MiB/191.25 MiB
# ⠙ Preparing packages... (0/1)m------------------ 82.20 MiB/191.25 MiB
# ⠙ Preparing packages... (0/1)m------------------ 82.36 MiB/191.25 MiB
# ⠙ Preparing packages... (0/1)m------------------ 82.59 MiB/191.25 MiB
# ⠙ Preparing packages... (0/1)m------------------ 82.64 MiB/191.25 MiB
# ⠹ Preparing packages... (0/1)m------------------ 82.69 MiB/191.25 MiB
# ⠹ Preparing packages... (0/1)m------------------ 82.87 MiB/191.25 MiB
# ⠹ Preparing packages... (0/1)2m----------------- 83.06 MiB/191.25 MiB
# ⠹ Preparing packages... (0/1)2m----------------- 83.29 MiB/191.25 MiB
# ⠹ Preparing packages... (0/1)2m----------------- 83.53 MiB/191.25 MiB
# ⠸ Preparing packages... (0/1)2m----------------- 83.81 MiB/191.25 MiB
# ⠸ Preparing packages... (0/1)2m----------------- 84.03 MiB/191.25 MiB
# ⠸ Preparing packages... (0/1)2m----------------- 84.28 MiB/191.25 MiB
# ⠼ Preparing packages... (0/1)2m----------------- 84.48 MiB/191.25 MiB
# ⠼ Preparing packages... (0/1)2m----------------- 84.62 MiB/191.25 MiB
# ⠼ Preparing packages... (0/1)2m----------------- 84.64 MiB/191.25 MiB
# ⠼ Preparing packages... (0/1)2m----------------- 84.72 MiB/191.25 MiB
# ⠼ Preparing packages... (0/1)2m----------------- 84.96 MiB/191.25 MiB
# ⠴ Preparing packages... (0/1)2m----------------- 85.14 MiB/191.25 MiB
# ⠴ Preparing packages... (0/1)2m----------------- 85.31 MiB/191.25 MiB
# ⠴ Preparing packages... (0/1)2m----------------- 85.47 MiB/191.25 MiB
# ⠦ Preparing packages... (0/1)2m----------------- 85.69 MiB/191.25 MiB
# ⠦ Preparing packages... (0/1)2m----------------- 85.86 MiB/191.25 MiB
# ⠦ Preparing packages... (0/1)2m----------------- 86.08 MiB/191.25 MiB
# ⠦ Preparing packages... (0/1)2m----------------- 86.26 MiB/191.25 MiB
# ⠦ Preparing packages... (0/1)2m----------------- 86.29 MiB/191.25 MiB
# ⠧ Preparing packages... (0/1)2m----------------- 86.37 MiB/191.25 MiB
# ⠧ Preparing packages... (0/1)2m----------------- 86.51 MiB/191.25 MiB
# ⠧ Preparing packages... (0/1)2m----------------- 86.70 MiB/191.25 MiB
# ⠧ Preparing packages... (0/1)2m----------------- 86.86 MiB/191.25 MiB
# ⠇ Preparing packages... (0/1)2m----------------- 87.06 MiB/191.25 MiB
# ⠇ Preparing packages... (0/1)2m----------------- 87.23 MiB/191.25 MiB
# ⠇ Preparing packages... (0/1)2m----------------- 87.45 MiB/191.25 MiB
# ⠇ Preparing packages... (0/1)2m----------------- 87.68 MiB/191.25 MiB
# ⠋ Preparing packages... (0/1)2m----------------- 87.90 MiB/191.25 MiB
# ⠋ Preparing packages... (0/1)2m----------------- 88.04 MiB/191.25 MiB
# ⠋ Preparing packages... (0/1)2m----------------- 88.06 MiB/191.25 MiB
# ⠋ Preparing packages... (0/1)2m----------------- 88.22 MiB/191.25 MiB
# ⠙ Preparing packages... (0/1)2m----------------- 88.36 MiB/191.25 MiB
# ⠙ Preparing packages... (0/1)2m----------------- 88.57 MiB/191.25 MiB
# ⠙ Preparing packages... (0/1)2m----------------- 88.75 MiB/191.25 MiB
# ⠙ Preparing packages... (0/1)2m----------------- 89.03 MiB/191.25 MiB
# ⠹ Preparing packages... (0/1)2m----------------- 89.25 MiB/191.25 MiB
# ⠹ Preparing packages... (0/1)---------------- 89.51 MiB/191.25 MiB
# ⠸ Preparing packages... (0/1)---------------- 89.75 MiB/191.25 MiB
# ⠸ Preparing packages... (0/1)---------------- 89.90 MiB/191.25 MiB
# ⠸ Preparing packages... (0/1)---------------- 89.92 MiB/191.25 MiB
# ⠸ Preparing packages... (0/1)---------------- 90.01 MiB/191.25 MiB
# ⠸ Preparing packages... (0/1)---------------- 90.03 MiB/191.25 MiB
# ⠸ Preparing packages... (0/1)---------------- 90.09 MiB/191.25 MiB
# ⠼ Preparing packages... (0/1)---------------- 90.23 MiB/191.25 MiB
# ⠼ Preparing packages... (0/1)---------------- 90.46 MiB/191.25 MiB
# ⠼ Preparing packages... (0/1)---------------- 90.60 MiB/191.25 MiB
# ⠼ Preparing packages... (0/1)---------------- 90.80 MiB/191.25 MiB
# ⠴ Preparing packages... (0/1)---------------- 90.99 MiB/191.25 MiB
# ⠦ Preparing packages... (0/1)---------------- 91.17 MiB/191.25 MiB
# ⠧ Preparing packages... (0/1)---------------- 91.31 MiB/191.25 MiB
# ⠇ Preparing packages... (0/1)---------------- 91.31 MiB/191.25 MiB
# ⠋ Preparing packages... (0/1)---------------- 91.31 MiB/191.25 MiB
# ⠙ Preparing packages... (0/1)---------------- 91.31 MiB/191.25 MiB
# ⠙ Preparing packages... (0/1)---------------- 91.31 MiB/191.25 MiB
# ⠙ Preparing packages... (0/1)---------------- 91.33 MiB/191.25 MiB
# ⠙ Preparing packages... (0/1)---------------- 91.34 MiB/191.25 MiB
# ⠙ Preparing packages... (0/1)---------------- 91.36 MiB/191.25 MiB
# ⠙ Preparing packages... (0/1)---------------- 91.37 MiB/191.25 MiB
# ⠙ Preparing packages... (0/1)---------------- 91.39 MiB/191.25 MiB
# ⠙ Preparing packages... (0/1)---------------- 91.40 MiB/191.25 MiB
# ⠹ Preparing packages... (0/1)---------------- 91.42 MiB/191.25 MiB
# ⠹ Preparing packages... (0/1)---------------- 91.42 MiB/191.25 MiB
# ⠹ Preparing packages... (0/1)---------------- 91.44 MiB/191.25 MiB
# ⠹ Preparing packages... (0/1)---------------- 91.45 MiB/191.25 MiB
# ⠹ Preparing packages... (0/1)---------------- 91.47 MiB/191.25 MiB
# ⠹ Preparing packages... (0/1)---------------- 91.48 MiB/191.25 MiB
# ⠹ Preparing packages... (0/1)---------------- 91.50 MiB/191.25 MiB
# ⠹ Preparing packages... (0/1)---------------- 91.51 MiB/191.25 MiB
# ⠹ Preparing packages... (0/1)---------------- 91.53 MiB/191.25 MiB
# ⠹ Preparing packages... (0/1)---------------- 91.55 MiB/191.25 MiB
# ⠹ Preparing packages... (0/1)---------------- 91.56 MiB/191.25 MiB
# ⠹ Preparing packages... (0/1)---------------- 91.58 MiB/191.25 MiB
# ⠹ Preparing packages... (0/1)---------------- 91.59 MiB/191.25 MiB
# ⠹ Preparing packages... (0/1)---------------- 91.61 MiB/191.25 MiB
# ⠹ Preparing packages... (0/1)---------------- 91.62 MiB/191.25 MiB
# ⠹ Preparing packages... (0/1)---------------- 91.65 MiB/191.25 MiB
# ⠸ Preparing packages... (0/1)---------------- 91.81 MiB/191.25 MiB
# ⠸ Preparing packages... (0/1)---------------- 91.92 MiB/191.25 MiB
# ⠸ Preparing packages... (0/1)---------------- 92.09 MiB/191.25 MiB
# ...
# ⠦ Preparing packages... (0/1)---------- 157.62 MiB/191.25 MiB
# ⠦ Preparing packages... (0/1)---------- 157.76 MiB/191.25 MiB
# ⠦ Preparing packages... (0/1)---------- 157.96 MiB/191.25 MiB
# ⠦ Preparing packages... (0/1)---------- 158.15 MiB/191.25 MiB
# ⠧ Preparing packages... (0/1)---------- 158.36 MiB/191.25 MiB
# ⠧ Preparing packages... (0/1)---------- 158.50 MiB/191.25 MiB
# ⠧ Preparing packages... (0/1)---------- 158.70 MiB/191.25 MiB
# ⠧ Preparing packages... (0/1)---------- 158.87 MiB/191.25 MiB
# ⠇ Preparing packages... (0/1)---------- 159.09 MiB/191.25 MiB
# ⠇ Preparing packages... (0/1)---------- 159.17 MiB/191.25 MiB
# ⠇ Preparing packages... (0/1)---------- 159.18 MiB/191.25 MiB
# ⠇ Preparing packages... (0/1)---------- 159.29 MiB/191.25 MiB
# ⠋ Preparing packages... (0/1)---------- 159.47 MiB/191.25 MiB
# ⠋ Preparing packages... (0/1)---------- 159.61 MiB/191.25 MiB
# ⠋ Preparing packages... (0/1)---------- 159.83 MiB/191.25 MiB
# ⠋ Preparing packages... (0/1)---------- 160.00 MiB/191.25 MiB
# ⠙ Preparing packages... (0/1)---------- 160.16 MiB/191.25 MiB
# ⠙ Preparing packages... (0/1)---------- 160.40 MiB/191.25 MiB
# ⠹ Preparing packages... (0/1)---------- 160.59 MiB/191.25 MiB
# ⠹ Preparing packages... (0/1)---------- 160.75 MiB/191.25 MiB
# ⠹ Preparing packages... (0/1)---------- 160.76 MiB/191.25 MiB
# ⠹ Preparing packages... (0/1)---------- 160.86 MiB/191.25 MiB
# ⠹ Preparing packages... (0/1)---------- 161.03 MiB/191.25 MiB
# ⠹ Preparing packages... (0/1)---------- 161.23 MiB/191.25 MiB
# ⠸ Preparing packages... (0/1)---------- 161.45 MiB/191.25 MiB
# ⠸ Preparing packages... (0/1)---------- 161.67 MiB/191.25 MiB
# ⠸ Preparing packages... (0/1)---------- 161.89 MiB/191.25 MiB
# ⠸ Preparing packages... (0/1)---------- 162.12 MiB/191.25 MiB
# ⠼ Preparing packages... (0/1)---------- 162.36 MiB/191.25 MiB
# ⠼ Preparing packages... (0/1)---------- 162.59 MiB/191.25 MiB
# ⠼ Preparing packages... (0/1)---------- 162.70 MiB/191.25 MiB
# ⠼ Preparing packages... (0/1)---------- 162.72 MiB/191.25 MiB
# ⠴ Preparing packages... (0/1)---------- 162.83 MiB/191.25 MiB
# ⠴ Preparing packages... (0/1)---------- 163.05 MiB/191.25 MiB
# ⠴ Preparing packages... (0/1)---------- 163.27 MiB/191.25 MiB
# ⠴ Preparing packages... (0/1)---------- 163.53 MiB/191.25 MiB
# ⠦ Preparing packages... (0/1)---------- 163.80 MiB/191.25 MiB
# ⠦ Preparing packages... (0/1)---------- 163.98 MiB/191.25 MiB
# ⠦ Preparing packages... (0/1)---------- 164.26 MiB/191.25 MiB
# ⠧ Preparing packages... (0/1)---------- 164.48 MiB/191.25 MiB
# ⠧ Preparing packages... (0/1)---------- 164.73 MiB/191.25 MiB
# ⠧ Preparing packages... (0/1)---------- 164.75 MiB/191.25 MiB
# ⠧ Preparing packages... (0/1)---------- 164.84 MiB/191.25 MiB
# ⠧ Preparing packages... (0/1)---------- 165.03 MiB/191.25 MiB
# ⠇ Preparing packages... (0/1)---------- 165.15 MiB/191.25 MiB
# ⠇ Preparing packages... (0/1)---------- 165.39 MiB/191.25 MiB
# ⠇ Preparing packages... (0/1)---------- 165.47 MiB/191.25 MiB
# ⠇ Preparing packages... (0/1)---------- 165.67 MiB/191.25 MiB
# ⠋ Preparing packages... (0/1)---------- 165.82 MiB/191.25 MiB
# ⠋ Preparing packages... (0/1)---------- 166.07 MiB/191.25 MiB
# ⠋ Preparing packages... (0/1)---------- 166.28 MiB/191.25 MiB
# ⠋ Preparing packages... (0/1)---------- 166.36 MiB/191.25 MiB
# ⠙ Preparing packages... (0/1)---------- 166.37 MiB/191.25 MiB
# ⠙ Preparing packages... (0/1)---------- 166.54 MiB/191.25 MiB
# ⠙ Preparing packages... (0/1)---------- 166.68 MiB/191.25 MiB
# ⠙ Preparing packages... (0/1)---------- 166.86 MiB/191.25 MiB
# ⠹ Preparing packages... (0/1)---------- 167.01 MiB/191.25 MiB
# ⠹ Preparing packages... (0/1)---------- 167.22 MiB/191.25 MiB
# ⠹ Preparing packages... (0/1)---------- 167.39 MiB/191.25 MiB
# ⠹ Preparing packages... (0/1)---------- 167.53 MiB/191.25 MiB
# ⠸ Preparing packages... (0/1)---------- 167.70 MiB/191.25 MiB
# ⠸ Preparing packages... (0/1)---------- 167.84 MiB/191.25 MiB
# ⠸ Preparing packages... (0/1)---------- 167.86 MiB/191.25 MiB
# ⠸ Preparing packages... (0/1)---------- 167.93 MiB/191.25 MiB
# ⠸ Preparing packages... (0/1)---------- 168.11 MiB/191.25 MiB
# ⠼ Preparing packages... (0/1)---------- 168.29 MiB/191.25 MiB
# ⠼ Preparing packages... (0/1)---------- 168.47 MiB/191.25 MiB
# ⠼ Preparing packages... (0/1)---------- 168.68 MiB/191.25 MiB
# ⠼ Preparing packages... (0/1)---------- 168.89 MiB/191.25 MiB
# ⠴ Preparing packages... (0/1)---------- 169.03 MiB/191.25 MiB
# ⠴ Preparing packages... (0/1)---------- 169.23 MiB/191.25 MiB
# ⠴ Preparing packages... (0/1)---------- 169.42 MiB/191.25 MiB
# ⠴ Preparing packages... (0/1)---------- 169.47 MiB/191.25 MiB
# ⠦ Preparing packages... (0/1)---------- 169.48 MiB/191.25 MiB
# ⠦ Preparing packages... (0/1)---------- 169.65 MiB/191.25 MiB
# ⠦ Preparing packages... (0/1)---------- 169.82 MiB/191.25 MiB
# ⠦ Preparing packages... (0/1)---------- 170.02 MiB/191.25 MiB
# ⠧ Preparing packages... (0/1)---------- 170.17 MiB/191.25 MiB
# ⠧ Preparing packages... (0/1)---------- 170.36 MiB/191.25 MiB
# ⠧ Preparing packages... (0/1)---------- 170.54 MiB/191.25 MiB
# ⠧ Preparing packages... (0/1)---------- 170.68 MiB/191.25 MiB
# ⠇ Preparing packages... (0/1)---------- 170.92 MiB/191.25 MiB
# ⠇ Preparing packages... (0/1)---------- 171.11 MiB/191.25 MiB
# ⠇ Preparing packages... (0/1)---------- 171.12 MiB/191.25 MiB
# ⠇ Preparing packages... (0/1)---------- 171.20 MiB/191.25 MiB
# ⠋ Preparing packages... (0/1)---------- 171.39 MiB/191.25 MiB
# ⠋ Preparing packages... (0/1)---------- 171.55 MiB/191.25 MiB
# ⠋ Preparing packages... (0/1)---------- 171.70 MiB/191.25 MiB
# ⠋ Preparing packages... (0/1)---------- 171.86 MiB/191.25 MiB
# ⠙ Preparing packages... (0/1)---------- 172.05 MiB/191.25 MiB
# ⠙ Preparing packages... (0/1)---------- 172.20 MiB/191.25 MiB
# ⠙ Preparing packages... (0/1)---------- 172.36 MiB/191.25 MiB
# ⠹ Preparing packages... (0/1)---------- 172.52 MiB/191.25 MiB
# ⠹ Preparing packages... (0/1)---------- 172.53 MiB/191.25 MiB
# ⠹ Preparing packages... (0/1)---------- 172.55 MiB/191.25 MiB
# ⠹ Preparing packages... (0/1)---------- 172.65 MiB/191.25 MiB
# ⠹ Preparing packages... (0/1)---------- 172.78 MiB/191.25 MiB
# ⠸ Preparing packages... (0/1)---------- 172.93 MiB/191.25 MiB
# ⠸ Preparing packages... (0/1)---------- 173.14 MiB/191.25 MiB
# ⠸ Preparing packages... (0/1)---------- 173.34 MiB/191.25 MiB
# ⠸ Preparing packages... (0/1)---------- 173.56 MiB/191.25 MiB
# ⠼ Preparing packages... (0/1)---------- 173.69 MiB/191.25 MiB
# ⠼ Preparing packages... (0/1)---------- 173.87 MiB/191.25 MiB
# ⠼ Preparing packages... (0/1)---------- 173.97 MiB/191.25 MiB
# ⠼ Preparing packages... (0/1)---------- 173.98 MiB/191.25 MiB
# ⠴ Preparing packages... (0/1)---------- 174.06 MiB/191.25 MiB
# ⠴ Preparing packages... (0/1)---------- 174.25 MiB/191.25 MiB
# ⠴ Preparing packages... (0/1)---------- 174.41 MiB/191.25 MiB
# ⠴ Preparing packages... (0/1)---------- 174.55 MiB/191.25 MiB
# ⠦ Preparing packages... (0/1)---------- 174.70 MiB/191.25 MiB
# ⠦ Preparing packages... (0/1)---------- 174.87 MiB/191.25 MiB
# ⠦ Preparing packages... (0/1)---------- 175.02 MiB/191.25 MiB
# ⠦ Preparing packages... (0/1)---------- 175.22 MiB/191.25 MiB
# ⠧ Preparing packages... (0/1)---------- 175.39 MiB/191.25 MiB
# ⠧ Preparing packages... (0/1)---------- 175.44 MiB/191.25 MiB
# ⠧ Preparing packages... (0/1)---------- 175.45 MiB/191.25 MiB
# ⠧ Preparing packages... (0/1)---------- 175.58 MiB/191.25 MiB
# ⠧ Preparing packages... (0/1)---------- 175.72 MiB/191.25 MiB
# ⠇ Preparing packages... (0/1)---------- 175.87 MiB/191.25 MiB
# ⠇ Preparing packages... (0/1)---------- 176.06 MiB/191.25 MiB
# ⠇ Preparing packages... (0/1)---------- 176.25 MiB/191.25 MiB
# ⠇ Preparing packages... (0/1)---------- 176.42 MiB/191.25 MiB
# ⠋ Preparing packages... (0/1)---------- 176.65 MiB/191.25 MiB
# ⠋ Preparing packages... (0/1)---------- 176.86 MiB/191.25 MiB
# ⠋ Preparing packages... (0/1)---------- 177.02 MiB/191.25 MiB
# ⠙ Preparing packages... (0/1)---------- 177.03 MiB/191.25 MiB
# ⠙ Preparing packages... (0/1)---------- 177.07 MiB/191.25 MiB
# ⠙ Preparing packages... (0/1)---------- 177.22 MiB/191.25 MiB
# ⠙ Preparing packages... (0/1)---------- 177.39 MiB/191.25 MiB
# ⠙ Preparing packages... (0/1)---------- 177.54 MiB/191.25 MiB
# ⠹ Preparing packages... (0/1)---------- 177.72 MiB/191.25 MiB
# ⠹ Preparing packages... (0/1)---------- 177.89 MiB/191.25 MiB
# ⠹ Preparing packages... (0/1)---------- 178.08 MiB/191.25 MiB
# ⠹ Preparing packages... (0/1)---------- 178.26 MiB/191.25 MiB
# ⠸ Preparing packages... (0/1)---------- 178.42 MiB/191.25 MiB
# ⠸ Preparing packages... (0/1)---------- 178.44 MiB/191.25 MiB
# ⠸ Preparing packages... (0/1)---------- 178.48 MiB/191.25 MiB
# ⠸ Preparing packages... (0/1)---------- 178.64 MiB/191.25 MiB
# ⠼ Preparing packages... (0/1)---------- 178.83 MiB/191.25 MiB
# ⠼ Preparing packages... (0/1)---------- 179.05 MiB/191.25 MiB
# ⠼ Preparing packages... (0/1)---------- 179.22 MiB/191.25 MiB
# ⠼ Preparing packages... (0/1)---------- 179.43 MiB/191.25 MiB
# ⠴ Preparing packages... (0/1)---------- 179.59 MiB/191.25 MiB
# ⠴ Preparing packages... (0/1)---------- 179.81 MiB/191.25 MiB
# ⠴ Preparing packages... (0/1)---------- 179.98 MiB/191.25 MiB
# ⠴ Preparing packages... (0/1)---------- 180.12 MiB/191.25 MiB
# ⠦ Preparing packages... (0/1)---------- 180.14 MiB/191.25 MiB
# ⠦ Preparing packages... (0/1)---------- 180.25 MiB/191.25 MiB
# ⠦ Preparing packages... (0/1)---------- 180.42 MiB/191.25 MiB
# ⠦ Preparing packages... (0/1)---------- 180.64 MiB/191.25 MiB
# ⠧ Preparing packages... (0/1)---------- 180.80 MiB/191.25 MiB
# ⠧ Preparing packages... (0/1)---------- 180.96 MiB/191.25 MiB
# ⠧ Preparing packages... (0/1)---------- 181.11 MiB/191.25 MiB
# ⠧ Preparing packages... (0/1)---------- 181.32 MiB/191.25 MiB
# ⠇ Preparing packages... (0/1)---------- 181.55 MiB/191.25 MiB
# ⠇ Preparing packages... (0/1)---------- 181.78 MiB/191.25 MiB
# ⠇ Preparing packages... (0/1)---------- 181.84 MiB/191.25 MiB
# ⠇ Preparing packages... (0/1)---------- 181.90 MiB/191.25 MiB
# ⠋ Preparing packages... (0/1)---------- 182.06 MiB/191.25 MiB
# ⠋ Preparing packages... (0/1)---------- 182.27 MiB/191.25 MiB
# ⠋ Preparing packages... (0/1)---------- 182.52 MiB/191.25 MiB
# ⠋ Preparing packages... (0/1)---------- 182.69 MiB/191.25 MiB
# ⠙ Preparing packages... (0/1)---------- 182.87 MiB/191.25 MiB
# ⠙ Preparing packages... (0/1)---------- 183.12 MiB/191.25 MiB
# ⠙ Preparing packages... (0/1)---------- 183.39 MiB/191.25 MiB
# ⠹ Preparing packages... (0/1)---------- 183.53 MiB/191.25 MiB
# ⠹ Preparing packages... (0/1)---------- 183.70 MiB/191.25 MiB
# ⠹ Preparing packages... (0/1)---------- 183.72 MiB/191.25 MiB
# ⠹ Preparing packages... (0/1)---------- 183.84 MiB/191.25 MiB
# ⠹ Preparing packages... (0/1)---------- 184.03 MiB/191.25 MiB
# ⠸ Preparing packages... (0/1)---------- 184.19 MiB/191.25 MiB
# ⠸ Preparing packages... (0/1)---------- 184.37 MiB/191.25 MiB
# ⠸ Preparing packages... (0/1)---------- 184.61 MiB/191.25 MiB
# ⠸ Preparing packages... (0/1)---------- 184.80 MiB/191.25 MiB
# ⠸ Preparing packages... (0/1)---------- 185.03 MiB/191.25 MiB
# ⠼ Preparing packages... (0/1)---------- 185.31 MiB/191.25 MiB
# ⠼ Preparing packages... (0/1)---------- 185.59 MiB/191.25 MiB
# ⠼ Preparing packages... (0/1)---------- 185.61 MiB/191.25 MiB
# ⠼ Preparing packages... (0/1)---------- 185.64 MiB/191.25 MiB
# ⠴ Preparing packages... (0/1)---------- 185.81 MiB/191.25 MiB
# ⠴ Preparing packages... (0/1)---------- 186.01 MiB/191.25 MiB
# ⠴ Preparing packages... (0/1)---------- 186.25 MiB/191.25 MiB
# ⠴ Preparing packages... (0/1)---------- 186.43 MiB/191.25 MiB
# ⠦ Preparing packages... (0/1)---------- 186.61 MiB/191.25 MiB
# ⠦ Preparing packages... (0/1)---------- 186.82 MiB/191.25 MiB
# ⠦ Preparing packages... (0/1)---------- 187.02 MiB/191.25 MiB
# ⠧ Preparing packages... (0/1)---------- 187.20 MiB/191.25 MiB
# ⠧ Preparing packages... (0/1)---------- 187.31 MiB/191.25 MiB
# ⠧ Preparing packages... (0/1)---------- 187.33 MiB/191.25 MiB
# ⠧ Preparing packages... (0/1)---------- 187.44 MiB/191.25 MiB
# ⠧ Preparing packages... (0/1)---------- 187.62 MiB/191.25 MiB
# ⠇ Preparing packages... (0/1)---------- 187.79 MiB/191.25 MiB
# ⠇ Preparing packages... (0/1)---------- 187.94 MiB/191.25 MiB
# ⠇ Preparing packages... (0/1)---------- 188.09 MiB/191.25 MiB
# ⠇ Preparing packages... (0/1)---------- 188.30 MiB/191.25 MiB
# ⠋ Preparing packages... (0/1)---------- 188.50 MiB/191.25 MiB
# ⠋ Preparing packages... (0/1)---------- 188.66 MiB/191.25 MiB
# ⠋ Preparing packages... (0/1)---------- 188.82 MiB/191.25 MiB
# ⠋ Preparing packages... (0/1)---------- 188.83 MiB/191.25 MiB
# ⠙ Preparing packages... (0/1)---------- 188.92 MiB/191.25 MiB
# ⠙ Preparing packages... (0/1)---------- 189.03 MiB/191.25 MiB
# ⠙ Preparing packages... (0/1)---------- 189.22 MiB/191.25 MiB
# ⠙ Preparing packages... (0/1)---------- 189.36 MiB/191.25 MiB
# ⠹ Preparing packages... (0/1)---------- 189.58 MiB/191.25 MiB
# ⠹ Preparing packages... (0/1)---------- 189.77 MiB/191.25 MiB
# ⠹ Preparing packages... (0/1)---------- 190.02 MiB/191.25 MiB
# ⠹ Preparing packages... (0/1)---------- 190.22 MiB/191.25 MiB
# ⠸ Preparing packages... (0/1)---------- 190.44 MiB/191.25 MiB
# ⠸ Preparing packages... (0/1)---------- 190.54 MiB/191.25 MiB
# ⠸ Preparing packages... (0/1)---------- 190.54 MiB/191.25 MiB
# ⠸ Preparing packages... (0/1)---------- 190.62 MiB/191.25 MiB
# ⠼ Preparing packages... (0/1)---------- 190.81 MiB/191.25 MiB
# ⠼ Preparing packages... (0/1)---------- 191.00 MiB/191.25 MiB
# Prepared 1 package in 59.28s
# Uninstalled 2 packages in 833ms
# Installed 45 packages in 642ms
#  + absl-py==2.4.0
#  + astunparse==1.6.3
#  + clip==1.0 (from git+https://github.com/openai/CLIP.git@ded190a052fdf4585bd685cee5bc96e0310d2c93)
#  + dm-tree==0.1.9
#  + docstring-parser==0.17.0
#  + einops==0.8.2
#  + etils==1.13.0
#  + flatbuffers==25.12.19
#  + ftfy==6.3.1
#  + gast==0.7.0
#  + google-pasta==0.2.0
#  + googleapis-common-protos==1.72.0
#  + grpcio==1.78.0
#  + immutabledict==4.3.1
#  + importlib-resources==6.5.2
#  + keras==3.13.2
#  + libclang==18.1.1
#  + markdown==3.10.2
#  + markdown-it-py==4.0.0
#  + mdurl==0.1.2
#  + ml-dtypes==0.5.4
#  + namex==0.1.0
#  - numpy==2.4.2
#  + numpy==2.2.6
#  + opencv-python==4.12.0.88
#  + opt-einsum==3.4.0
#  + optree==0.18.0
#  + promise==2.3
#  + protobuf==6.33.5
#  + pyarrow==23.0.1
#  + regex==2026.1.15
#  + rich==14.3.2
#  + simple-parsing==0.1.8
#  + tensorboard==2.20.0
#  + tensorboard-data-server==0.7.2
#  + tensorflow==2.20.0
#  + tensorflow-datasets==4.9.9
#  + tensorflow-metadata==1.17.3
#  + termcolor==3.3.0
#  + toml==0.10.2
#  - torch==2.10.0
#  + torch==2.9.1
#  + torchvision==0.24.1
#  + werkzeug==3.1.5
#  + wheel==0.46.3
#  + wrapt==2.1.1
#  + zipp==3.23.0
# ✅ Setup complete. Environment '.venv' is now active.

# %% [markdown]
# ## `conda` (legacy)

# %%
# uncomment to use conda
# if IN_COLAB:
#     !pip install -q condacolab
#     import condacolab
#     condacolab.install()
#     %cd $WORK_DIR/src
#     !conda env create -f environment.yml
#     !exec bash
# else:
#     %cd $WORK_DIR/src
#     !conda env create -f environment.yml

# %% [markdown]
# ---

# %% [markdown]
# <a id="assignment-content"></a>
#
# # Assignment Content

# %% [markdown]
# # Image features exercise
#
# We have seen that we can achieve reasonable performance on an image classification task by training a linear classifier on the pixels of the input image. In this exercise we will show that we can improve our classification performance by training linear classifiers not on raw pixels but on features that are computed from the raw pixels.
#
# All of your work for this exercise will be done in this notebook.

# %%
import random
import numpy as np
import os, sys

if os.path.basename(os.getcwd()) != "submission":
    os.chdir("src/submission")

# Ensure package import works
if os.getcwd() not in sys.path:
    sys.path.insert(0, os.getcwd())

print("cwd:", os.getcwd())

from xcs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt


# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2
# Out:
# cwd: /Users/sj/code/xcs231n/XCS231N-A1/src/submission
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Load data
# Similar to previous exercises, we will load CIFAR-10 data from disk.

# %%
from xcs231n.features import color_histogram_hsv, hog_feature

def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000):
    # Load the raw CIFAR-10 data
    cifar10_dir = 'xcs231n/datasets/cifar-10-batches-py'

    # Cleaning up variables to prevent loading data multiple times (which may cause memory issue)
    try:
       del X_train, y_train
       del X_test, y_test
       print('Clear previously loaded data.')
    except:
       pass

    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)

    # Subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]

    return X_train, y_train, X_val, y_val, X_test, y_test

X_train, y_train, X_val, y_val, X_test, y_test = get_CIFAR10_data()
# Out:
# /Users/sj/code/xcs231n/XCS231N-A1/src/submission/xcs231n/data_utils.py:16: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   return pickle.load(f, encoding="latin1")

# %% [markdown]
# ## Extract Features
# For each image we will compute a Histogram of Oriented
# Gradients (HOG) as well as a color histogram using the hue channel in HSV
# color space. We form our final feature vector for each image by concatenating
# the HOG and color histogram feature vectors.
#
# Roughly speaking, HOG should capture the texture of the image while ignoring
# color information, and the color histogram represents the color of the input
# image while ignoring texture. As a result, we expect that using both together
# ought to work better than using either alone. Verifying this assumption would
# be a good thing to try for your own interest.
#
# The `hog_feature` and `color_histogram_hsv` functions both operate on a single
# image and return a feature vector for that image. The extract_features
# function takes a set of images and a list of feature functions and evaluates
# each feature function on each image, storing the results in a matrix where
# each column is the concatenation of all feature vectors for a single image.

# %%
from xcs231n.features import *
# produce an output shape of : (N, F_total) N is num of training data for X_train_feats
# Takes many images imgs with shape (N, H, W, C) CIFAR: (5000, 32, 32, 3), for each feature functions feature_fns, compute features on each images and concatenate all feature outpputs into one vector
# num_color_bins = 10 # Number of bins in the color histogram
num_color_bins = 25 # Number of bins in the color histogram
feature_fns = [hog_feature, lambda img: color_histogram_hsv(img, nbin=num_color_bins)]
# X_train_feats shape is (num_training, hog_dim + num_color_bins)
X_train_feats = extract_features(X_train, feature_fns, verbose=True)
X_val_feats = extract_features(X_val, feature_fns)
X_test_feats = extract_features(X_test, feature_fns)

# Preprocessing: Subtract the mean feature
mean_feat = np.mean(X_train_feats, axis=0, keepdims=True)
X_train_feats -= mean_feat
X_val_feats -= mean_feat
X_test_feats -= mean_feat

# Preprocessing: Divide by standard deviation. This ensures that each feature
# has roughly the same scale.
std_feat = np.std(X_train_feats, axis=0, keepdims=True)
X_train_feats /= std_feat
X_val_feats /= std_feat
X_test_feats /= std_feat

# Preprocessing: Add a bias dimension , hstack merge arr horizontally (col+col)
X_train_feats = np.hstack([X_train_feats, np.ones((X_train_feats.shape[0], 1))])
X_val_feats = np.hstack([X_val_feats, np.ones((X_val_feats.shape[0], 1))])
X_test_feats = np.hstack([X_test_feats, np.ones((X_test_feats.shape[0], 1))])
# Out:
# Done extracting features for 1000 / 49000 images
# Done extracting features for 2000 / 49000 images
# Done extracting features for 3000 / 49000 images
# Done extracting features for 4000 / 49000 images
# Done extracting features for 5000 / 49000 images
# Done extracting features for 6000 / 49000 images
# Done extracting features for 7000 / 49000 images
# Done extracting features for 8000 / 49000 images
# Done extracting features for 9000 / 49000 images
# Done extracting features for 10000 / 49000 images
# Done extracting features for 11000 / 49000 images
# Done extracting features for 12000 / 49000 images
# Done extracting features for 13000 / 49000 images
# Done extracting features for 14000 / 49000 images
# Done extracting features for 15000 / 49000 images
# Done extracting features for 16000 / 49000 images
# Done extracting features for 17000 / 49000 images
# Done extracting features for 18000 / 49000 images
# Done extracting features for 19000 / 49000 images
# Done extracting features for 20000 / 49000 images
# Done extracting features for 21000 / 49000 images
# Done extracting features for 22000 / 49000 images
# Done extracting features for 23000 / 49000 images
# Done extracting features for 24000 / 49000 images
# Done extracting features for 25000 / 49000 images
# Done extracting features for 26000 / 49000 images
# Done extracting features for 27000 / 49000 images
# Done extracting features for 28000 / 49000 images
# Done extracting features for 29000 / 49000 images
# Done extracting features for 30000 / 49000 images
# Done extracting features for 31000 / 49000 images
# Done extracting features for 32000 / 49000 images
# Done extracting features for 33000 / 49000 images
# Done extracting features for 34000 / 49000 images
# Done extracting features for 35000 / 49000 images
# Done extracting features for 36000 / 49000 images
# Done extracting features for 37000 / 49000 images
# Done extracting features for 38000 / 49000 images
# Done extracting features for 39000 / 49000 images
# Done extracting features for 40000 / 49000 images
# Done extracting features for 41000 / 49000 images
# Done extracting features for 42000 / 49000 images
# Done extracting features for 43000 / 49000 images
# Done extracting features for 44000 / 49000 images
# Done extracting features for 45000 / 49000 images
# Done extracting features for 46000 / 49000 images
# Done extracting features for 47000 / 49000 images
# Done extracting features for 48000 / 49000 images
# Done extracting features for 49000 / 49000 images

# %% [markdown]
# ## Train Softmax classifier on features
# Using the Softmax code developed earlier in the assignment, train Softmax classifiers on top of the features extracted above; this should achieve better results than training them directly on top of raw pixels.

# %%
# Use the validation set to tune the learning rate and regularization strength

from xcs231n.classifiers.linear_classifier import Softmax

learning_rates = [1e-7, 1e-6]
regularization_strengths = [5e5, 5e6]

results = {}
best_val = -1
best_softmax = None

################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the Softmax; save#
# the best trained classifer in best_softmax. If you carefully tune the model, #
# you should be able to get accuracy of above 0.42 on the validation set.      #
################################################################################
# ### START CODE HERE ###
for l in learning_rates:
    for reg in regularization_strengths:
        softmax = Softmax()
        losses = softmax.train(X_train_feats, y_train, learning_rate=l,reg=reg, num_iters = 1500, batch_size=200, verbose = False)
        y_train_pred = softmax.predict(X_train_feats)
        train_accuracy = np.mean(y_train_pred == y_train)

        y_val_pred = softmax.predict(X_val_feats)
        val_accuracy = np.mean(y_val_pred == y_val)
        results[(l, reg)] = (train_accuracy, val_accuracy)
        if val_accuracy > best_val:
            best_val = val_accuracy
            best_softmax = softmax  

# ### END CODE HERE ###

# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))

print('best validation accuracy achieved: %f' % best_val)
# Out:
# lr 1.000000e-07 reg 5.000000e+05 train accuracy: 0.425816 val accuracy: 0.436000
# lr 1.000000e-07 reg 5.000000e+06 train accuracy: 0.341020 val accuracy: 0.336000
# lr 1.000000e-06 reg 5.000000e+05 train accuracy: 0.345041 val accuracy: 0.365000
# lr 1.000000e-06 reg 5.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# best validation accuracy achieved: 0.436000

# %%
# Evaluate your trained Softmax on the test set: you should be able to get at least 0.42
y_test_pred = best_softmax.predict(X_test_feats)
test_accuracy = np.mean(y_test == y_test_pred)
print(test_accuracy)
# Out:
# 0.427

# %%
# Save best softmax model
best_softmax.save("best_softmax_features.npy")
# Out:
# best_softmax_features.npy saved.

# %%
# An important way to gain intuition about how an algorithm works is to
# visualize the mistakes that it makes. In this visualization, we show examples
# of images that are misclassified by our current system. The first column
# shows images that our system labeled as "plane" but whose true label is
# something other than "plane".

examples_per_class = 8
classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for cls, cls_name in enumerate(classes):
    idxs = np.where((y_test != cls) & (y_test_pred == cls))[0]
    idxs = np.random.choice(idxs, examples_per_class, replace=False)
    for i, idx in enumerate(idxs):
        plt.subplot(examples_per_class, len(classes), i * len(classes) + cls + 1)
        plt.imshow(X_test[idx].astype('uint8'))
        plt.axis('off')
        if i == 0:
            plt.title(cls_name)
plt.show()

# %% [markdown]
# ### Inline question 1:
# Describe the misclassification results that you see. Do they make sense?
#
#
# $\color{blue}{\textit Your Answer:}$
#
# ### START ANSWER HERE ###
# I saw that for example the first column, at row 5,fog is misclassed as plane because it's shape is similar to plane, and the same for the other columns.
# ### END ANSWER HERE ###

# %% [markdown]
# ## Neural Network on image features
# Earlier in this assigment we saw that training a two-layer neural network on raw pixels achieved better classification performance than linear classifiers on raw pixels. In this notebook we have seen that linear classifiers on image features outperform linear classifiers on raw pixels.
#
# For completeness, we should also try training a neural network on image features. This approach should outperform all previous approaches: you should easily be able to achieve over 55% classification accuracy on the test set; our best model achieves about 60% classification accuracy.

# %%
# Preprocessing: Remove the bias dimension
# Make sure to run this cell only ONCE
print(X_train_feats.shape)
X_train_feats = X_train_feats[:, :-1]
X_val_feats = X_val_feats[:, :-1]
X_test_feats = X_test_feats[:, :-1]

print(X_train_feats.shape)
# Out:
# (49000, 170)
# (49000, 169)

# %%
from xcs231n.classifiers.fc_net import TwoLayerNet
from xcs231n.solver import Solver

input_dim = X_train_feats.shape[1]
hidden_dim = 500
num_classes = 10

data = {
    'X_train': X_train_feats,
    'y_train': y_train,
    'X_val': X_val_feats,
    'y_val': y_val,
    'X_test': X_test_feats,
    'y_test': y_test,
}

net = TwoLayerNet(input_dim, hidden_dim, num_classes)
best_net = None

################################################################################
# TODO: Train a two-layer neural network on image features. You may want to    #
# cross-validate various parameters as in previous sections. Store your best   #
# model in the best_net variable.                                              #
################################################################################
# ### START CODE HERE ###
best_val = -1
best_config = None

# num for PCA (reduced dimension)

# bigger hidden size can increase model capacity, too small results in underfitting
learning_rates = [1e-3,1e-1]
regularization_strengths = [1e-4,1e-2]
hidden_size = [128, 256]
num_epochs = [6]
lr_decay = [0.95,0.99]
weight_scale = [1e-3, 5e-3]
num_classes = 10

num_tune_train = 5000
small_data = {
    "X_train": data["X_train"][:num_tune_train],
    "y_train": data["y_train"][:num_tune_train],
    "X_val": data["X_val"],
    "y_val": data["y_val"],
}
results = [] #(val_acc, config, model)
for lr in learning_rates:
    for r in regularization_strengths:
        for h in hidden_size:
            for epoch in num_epochs:
                for decay in lr_decay:
                    for w in weight_scale:
                        config = {
                            "learning_rate": lr,
                            "r": r,
                            "h": h,
                            "decay": decay,
                            "weight_scale": w,
                            "num_epochs": epoch
                        }
                        model = TwoLayerNet(input_dim, h, num_classes,w,r)
                        solver = Solver(model=model, data=small_data,
                                        update_rule='sgd',
                                            optim_config={
                                            'learning_rate': lr
                                            },
                                            lr_decay=decay,
                                            num_epochs=epoch, batch_size=200,
                                            verbose=False,
                                            print_every=200)
                        solver.train()
                        # Solver already tracks the best validation accuracy during training.
                        y_val_acc = solver.best_val_acc
                        results.append((y_val_acc,config,model))
                        if y_val_acc > best_val:
                            best_val = y_val_acc
                            best_net = model
                            best_config = config
    
results.sort(key=lambda x: x[0],reverse=True)
top_configs = [r[1] for r in results[:1]]
print(f"first tuning: val_acc={best_val:.4f}, cfg={top_configs}")

better_results = []
fine_epochs = [20,40]
for config in top_configs:
    lr = config["learning_rate"]
    lrs = [lr,lr*2.0 ]
    for fine_lr in lrs:
        for ep in fine_epochs:
            model = TwoLayerNet(input_dim,config["h"], num_classes, config["weight_scale"],config["r"])
            solver = Solver(model=model, data=data,
                                        update_rule='sgd',
                                            optim_config={
                                            'learning_rate': fine_lr
                                            },
                                            lr_decay=config["decay"],
                                            num_epochs=ep, batch_size=200,
                                            verbose=False,
                                            print_every=200)
            solver.train()
            y_val_acc = solver.best_val_acc
            fine_config = dict(config)
            fine_config["learning_rate"] = fine_lr
            fine_config["num_epochs"] = ep
            
            better_results.append((y_val_acc,fine_config,model))
            if y_val_acc > best_val:
                best_val = y_val_acc
                best_net = model
                best_config = fine_config
print(f"Best validation accuracy: {best_val:.4f}")
print("Best config:", best_config) 
# ### END CODE HERE ###
# Out:
# first tuning: val_acc=0.3950, cfg=[{'learning_rate': 0.1, 'r': 0.0001, 'h': 256, 'decay': 0.99, 'weight_scale': 0.005, 'num_epochs': 6}]
# Best validation accuracy: 0.6170
# Best config: {'learning_rate': 0.1, 'r': 0.0001, 'h': 256, 'decay': 0.99, 'weight_scale': 0.005, 'num_epochs': 40}

# %%
# Run your best neural net classifier on the test set. You should be able
# to get more than 58% accuracy. It is also possible to get >60% accuracy
# with careful tuning.

y_test_pred = np.argmax(best_net.loss(data['X_test']), axis=1)
test_acc = (y_test_pred == data['y_test']).mean()
print(test_acc)
# Out:
# 0.581

# %%
# Save best model
best_net.save("best_two_layer_net_features.npy")
# Out:
# best_two_layer_net_features.npy saved.

# %%
for k, v in best_net.params.items():
  print(k, v.shape)
print(X_train_feats.shape)
print(best_softmax.W.shape)
# Out:
# W1 (169, 256)
# b1 (256,)
# W2 (256, 10)
# b2 (10,)
# (49000, 169)
# (170, 10)

# %% [markdown]
# # Submission
#
# **You will need to submit the answers from this notebook on Gradescope.**
